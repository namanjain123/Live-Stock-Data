# %%
# This is the one to get the real time stock price by google crawling this work for both indian and other nation countries.

# %%
#Main Import Files
from bs4 import BeautifulSoup
import requests
import time

# %%
# Get The url info for some start then see the function and use this as an example and make a function
url='https://www.google.com/search?q=reliance+share'
HTML=requests.get(url)
#parse ir
soup=BeautifulSoup(HTML.text,'html.parser')
#print the price of crpto currency price
print(soup.prettify())
# The Class that is being used is <div class="BNeawe iBp4i AP7Wnd">
# Out:
# <!DOCTYPE doctype html>
# <html lang="zh-TW">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    reliance share - Google 搜尋
#   </title>
#   <script nonce="JLYGQWZhtzn2wnErV0VdJg==">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
#Function To get current stock price
def get_stock_price(stock):
  url='https://www.google.com/search?q='+stock+'+share'
  HTML=requests.get(url)
  soup=BeautifulSoup(HTML.text,'html.parser')
  #Find The Current Price
  text=soup.find('div',attrs={'class':'BNeawe iBp4i AP7Wnd'}).find('div',attrs={'class':'BNeawe iBp4i AP7Wnd'}).text
  #return the text
  return text.partition(' ')[0]
get_stock_price('LTTS')
# Out:
# '3,843.70'

# %%
#Get the live data very easily updated
def live_stock(stock):
  last_price=-1
  #create a loop to continuesly show the price
  while True:
    #Choose The Crypto currency Price
    #get the price
    price=get_stock_price(stock)
    if price !=last_price:
      print(stock+'  price',price)
      last_price=price
    time.sleep(2)

# %%
# <span class="r0bn4c rQMQod">
#  <div class="BNeawe s3v9rd AP7Wnd">

# %%
class Stock:
    stock=''
    def __init__(self, stock):
      self.stock = stock
    url='https://www.google.com/search?q='+stock+'+share'
    HTML=requests.get(url)
    soup=BeautifulSoup(HTML.text,'html.parser')
    def current_stock_price():
      text=soup.find('div',attrs={'class':'BNeawe iBp4i AP7Wnd'}).find('div',attrs={'class':'BNeawe iBp4i AP7Wnd'}).text
      return text.partition(' ')[0]
    def live_stock():
      last_price=-1
      #create a loop to continuesly show the price
      while True:
        #Choose The Crypto currency Price
        #get the price
        price=get_stock_price()
        if price !=last_price:
          print(stock+'  price',price)
          last_price=price
        time.sleep(2)
    def high_52():
      text=soup.find_all('span',attrs={'class':'r0bn4c rQMQod'})
      high_52=text[8].string
      high_52=high_52.partition(' ')[0]
      return(high_52)
    def market_cap():
      print(self.stock)
      text=self.soup.find_all('span',attrs={'class':'r0bn4c rQMQod'})
      market_cap=text[12].string
      #return(text)
    def low_52():
      text=soup.find_all('span',attrs={'class':'r0bn4c rQMQod'})
      low_52=text[11].string
      low_52=low.partition(' ')[0]
      return(low_52)
